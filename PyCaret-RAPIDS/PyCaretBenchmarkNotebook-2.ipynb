# %%
from platform import python_version

print(python_version())

# %%
import pycaret

import pandas as pd
import numpy as np

from pycaret.utils import version
version()
# Out:
# '2.3.10'

# %%
import json
import time

class Timer:
    def __enter__(self, *args, **kwargs):
        self.tick = time.time()
        return self
    
    def __exit__(self, *args, **kwargs):
        self.elapsed = time.time() - self.tick
        
benchmark_list = []

# %%
# Begin Boiler Plate Code, will have few quick sample commands to run at the end

# Data file is from https://archive.ics.uci.edu/ml/machine-learning-databases
dataset = pd.read_csv('data/YearPredictionMSD.txt')

# %%
# Fixing attribute labels
categorical_feature_names = ['Year']
numeric_feature_names = []
for x in range(1,13):
    numeric_feature_names.append('t_avg_' + str(x)) # These attributes are timbre averages
for x in range(1,79):
    numeric_feature_names.append('t_cov_' + str(x)) # These attributes are timbre covariances
dataset.columns = [*categorical_feature_names, *numeric_feature_names]

dataset.head()
# Out:
#    Year   t_avg_1   t_avg_2   t_avg_3   t_avg_4   t_avg_5   t_avg_6   t_avg_7  \
# 0  2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777   8.76630
# 1  2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940  -3.27872
# 2  2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683   5.05097
# 3  2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409 -12.48207
# 4  2001  50.54767   0.31568  92.35066  22.38696 -25.51870 -19.04928  20.67345
#
#     t_avg_8   t_avg_9  ...  t_cov_69   t_cov_70  t_cov_71  t_cov_72  t_cov_73  \
# 0  -0.92019  18.76548  ...   5.66812  -19.68073  33.04964  42.87836  -9.90378
# 1  -2.35035  16.07017  ...   3.03800   26.05866 -50.92779  10.93792  -0.07568
# 2 -10.34124   3.55005  ...  34.57337 -171.70734 -16.96705 -46.67617 -12.51516
# 3  -9.37636  12.63699  ...   9.92661  -55.95724  64.92712 -17.72522  -1.49237
# 4  -5.19943   3.63566  ...   6.59753  -50.69577  26.02574  18.94430  -0.33730
#
#    t_cov_74   t_cov_75  t_cov_76   t_cov_77  t_cov_78
# 0 -32.22788   70.49388  12.04941   58.43453  26.92061
# 1  43.20130 -115.00698  -0.05859   39.67068  -0.66345
# 2  82.58061  -72.08993   9.90558  199.62971  18.85382
# 3  -7.50035   51.76631   7.88713   55.66926  28.74903
# 4   6.09352   35.18381   5.00283  -11.02257   0.02263
#
# [5 rows x 91 columns]

# %%
# Split Dataset into Training and Test
df = dataset[:463716]
unseen_df = dataset[463716:515346]
unseen_df.reset_index(drop=True, inplace=True)

print('Data for Modeling: ' + str(df.shape))
print('Unseen Data For Predictions: ' + str(unseen_df.shape))
# Out:
# Data for Modeling: (463716, 91)
# Unseen Data For Predictions: (51628, 91)

# %%
# from pycaret.regression import *

# exp_reg = setup(data=df, target='Year', session_id=123, normalize=True, use_gpu=False, 
# numeric_features=numeric_feature_names, silent=True, fold=3)
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              22:12:33
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12746/1120720352.py in <module>
#       2
#       3 exp_reg = setup(data=df, target='Year', session_id=123, normalize=True, use_gpu=False,
# ----> 4 numeric_features=numeric_feature_names, silent=True)
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/pycaret/regression.py in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     666         verbose=verbose,
#     667         profile=profile,
# --> 668         profile_kwargs=profile_kwargs,
#     669     )
#     670
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/pycaret/internal/tabular.py in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1406             test_data = pd.concat([X_test, y_test], axis=1)
#    1407
# -> 1408         train_data = prep_pipe.fit_transform(train_data)
#    1409         # workaround to also transform target
#    1410         dtypes.final_training_columns.append(target)
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     365         """
#     366         fit_params_steps = self._check_fit_params(**fit_params)
# --> 367         Xt = self._fit(X, y, **fit_params_steps)
#     368
#     369         last_step = self._final_estimator
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     294                 message_clsname='Pipeline',
#     295                 message=self._log_message(step_idx),
# --> 296                 **fit_params_steps[name])
#     297             # Replace the transformer of the step with the fitted
#     298             # transformer. This is necessary when loading the transformer
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     738     with _print_elapsed_time(message_clsname, message):
#     739         if hasattr(transformer, 'fit_transform'):
# --> 740             res = transformer.fit_transform(X, y, **fit_params)
#     741         else:
#     742             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/pycaret/internal/preprocess.py in fit_transform(self, dataset, y)
#     419
#     420         # since this is for training , we dont nees any transformation since it has already been transformed in fit
# --> 421         data = self.fit(data)
#     422
#     423         # additionally we just need to treat the target variable
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/pycaret/internal/preprocess.py in fit(self, dataset, y)
#     192             # count how many digits are there that have decimiles
#     193             count_float = np.nansum(
# --> 194                 [False if r.is_integer() else True for r in data[i]]
#     195             )
#     196             # total decimiels digits
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/pycaret/internal/preprocess.py in <listcomp>(.0)
#     192             # count how many digits are there that have decimiles
#     193             count_float = np.nansum(
# --> 194                 [False if r.is_integer() else True for r in data[i]]
#     195             )
#     196             # total decimiels digits
#
# KeyboardInterrupt:

# %%
# NOTE: commented out because this take a really long time and doesn't showcase GPU usage

# with Timer() as elapsed:
#     best_models = compare_models(exclude = ['ransac'], n_select = 3)
    
# benchmark_payload = {}
# benchmark_payload["function"] = "compare models"
# benchmark_payload["model"] = "all"
# benchmark_payload["processor"] = "cpu"
# benchmark_payload["fit_time"] = elapsed.elapsed

# benchmark_list.append(benchmark_payload)
# Out:
# <style  type="text/css" >
#     #T_8ca01206_c840_11ec_b653_00155d40b68a th {
#           text-align: left;
#     }#T_8ca01206_c840_11ec_b653_00155d40b68arow0_col0,#T_8ca01206_c840_11ec_b653_00155d40b68arow1_col0,#T_8ca01206_c840_11ec_b653_00155d40b68arow1_col1,#T_8ca01206_c840_11ec_b653_00155d40b68arow1_col2,#T_8ca01206_c840_11ec_b653_00155d40b68arow1_col3,#T_8ca01206_c840_11ec_b653_00155d40b68arow1_col4,#T_8ca01206_c840_11ec_b653_00155d40b68arow2_col0,#T_8ca01206_c840_11ec_b653_00155d40b68arow2_col1,#T_8ca01206_c840_11ec
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_8ca01206_c840_11ec_b653_00155d40b68arow14_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_8ca01206_c840_11ec_b653_00155d40b68a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RM

# %%
# NOTE: I didn't bother running the rest of the PyCaret commands with CPU after I created the CPU usage cells
# Create Model (Linear Regression)

# with Timer() as elapsed:
#     lr = create_model('lr', fold = 5)

# benchmark_payload = {}
# benchmark_payload["function"] = "create model cpu"
# benchmark_payload["model"] = "lr"
# benchmark_payload["processor"] = "cpu"
# benchmark_payload["fit_time"] = elapsed.elapsed

# benchmark_list.append(benchmark_payload)

# %%
# Tune the Linear Regression Model
# with Timer() as elasped:
#     tuned_lr = tune_model(lr)
    
# benchmark_payload = {}
# benchmark_payload["function"] = "tune model cpu"
# benchmark_payload["model"] = "lr"
# benchmark_payload["processor"] = "cpu"
# benchmark_payload["fit_time"] = elapsed.elapsed

# benchmark_list.append(benchmark_payload)

# %%
# Ensemble a Model

# %%
# Blender Ensemble Model
# with Timer() as elapsed:
#     # Train individual models to blend

#     # excluding xgboost since cannot run on GPU for comparison
#     # xgboost = create_model('xgboost', verbose = False)
#     lr = create_model('lr', verbose = False)
#     knn = create_model('knn', verbose = False)
    
#     # Blend individual models
#     blender = blend_models(estimator_list = [lr, knn])
    
# benchmark_payload = {}
# benchmark_payload["function"] = "ensemble - blending cpu"
# benchmark_payload["model"] = "Blending lr, knn"
# benchmark_payload["processor"] = "cpu"
# benchmark_payload["fit_time"] = elapsed.elapsed

# benchmark_list.append(benchmark_payload)

# %%
# Stacking Ensemble Model
# with Timer() as elapsed:
#     stacker = stack_models(best_models)

# benchmark_payload = {}
# benchmark_payload["function"] = "ensemble - stacking cpu"
# benchmark_payload["model"] = "best_models cpu"
# benchmark_payload["processor"] = "cpu"
# benchmark_payload["fit_time"] = elapsed.elapsed

# benchmark_list.append(benchmark_payload)

# %%
# Plot Error
# plot_model(blender, plot = 'error')
# plot_model(stacker, plot = 'error')

# %%
# Predict on Hold-Out Sample
# with Timer() as elapsed:
#     predict_model(stacker);
    
# benchmark_payload = {}
# benchmark_payload["function"] = "predict model cpu"
# benchmark_payload["model"] = "stacker"
# benchmark_payload["processor"] = "cpu"
# benchmark_payload["fit_time"] = elapsed.elapsed

# benchmark_list.append(benchmark_payload)

# %%
# Finalize Stacker Ensemble Model and predict with it
# with Timer() as elapsed:
#     final_stacker = finalize_model(stacker)
    
# benchmark_payload = {}
# benchmark_payload["function"] = "finalize model cpu"
# benchmark_payload["model"] = "stacker"
# benchmark_payload["processor"] = "cpu"
# benchmark_payload["fit_time"] = elapsed.elapsed

# benchmark_list.append(benchmark_payload)
# with Timer() as elapsed:
#     predict_model(final_stacker);

# benchmark_payload = {}
# benchmark_payload["function"] = "predict model cpu"
# benchmark_payload["model"] = "final stacker"
# benchmark_payload["processor"] = "cpu"
# benchmark_payload["fit_time"] = elapsed.elapsed

# benchmark_list.append(benchmark_payload)

# %%
# Predict on Unseen Data with the Stack Ensemble Model
# with Timer() as elapsed:
#     unseen_predictions = predict_model(final_stacker, data=unseen_df)
#     unseen_predictions.head()
    
# benchmark_payload = {}
# benchmark_payload["function"] = "predict on unseen cpu"
# benchmark_payload["model"] = "final stacker"
# benchmark_payload["processor"] = "cpu"
# benchmark_payload["fit_time"] = elapsed.elapsed

# benchmark_list.append(benchmark_payload)

# %%
# Try GPU
from pycaret.regression import *

exp_reg = setup(data=df, target='Year', session_id=123, normalize=True, use_gpu=True, 
numeric_features=numeric_feature_names, silent=True, fold=3)
# Out:
# <style  type="text/css" >
# #T_1cf6659a_c9b2_11ec_9756_00155d40b68arow16_col1,#T_1cf6659a_c9b2_11ec_9756_00155d40b68arow27_col1,#T_1cf6659a_c9b2_11ec_9756_00155d40b68arow42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_1cf6659a_c9b2_11ec_9756_00155d40b68a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1cf6659a_c9b2_11ec_9756_00155d40b68alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_1cf6659a_c9b2_11ec_9756_00155d40b68alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow1_col1" class="data row1 col1" >Year</td>
#             </tr>
#             <tr>
#                         <th id="T_1cf6659a_c9b2_11ec_9756_00155d40b68alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow2_col1" class="data row2 col1" >(463716, 91)</td>
#             </tr>
#             <tr>
#                         <th id="T_1cf6659a_c9b2_11ec_9756_00155d40b68alevel0_row3" class="row_heading level0 row3" >3</th>
#                         <th id="T_1cf6659a_c9b2_11ec_9756_00155d40b68alevel0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_1cf6659a_c9b2_11ec_9756_00155d40b68alevel0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1cf6659a_c9b2_11ec_9756_00155d40b68alevel0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_1cf6659a_c9b2_11ec_9756_00155d40b68alevel0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow14_col1" class="data row14 col1" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_1cf6659a_c9b2_11ec_9756_00155d40b68alevel0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_1cf6659a_c9b2_11ec_9756_00155d40b68alevel0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow16_col1" class="data row16 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_1cf6659a_c9b2_11ec_9756_00155d40b68alevel0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_1cf6659a_c9b2_11ec_9756_00155d40b68alevel0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_1cf6659a_c9b2_11ec_9756_00155d40b68arow18_col0" class="data row18 col0" >

# %%
# Exclude all non-GPU models and copy to rest
non_gpu_models = ['ransac', 'huber', 'par', 'ada', 'omp', 'llar']
with Timer() as elapsed:
#             text-align:  left;
#             text-align:  left;
#         }#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col1,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col2,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col3,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col4,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col5,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col7,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow1_col7,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow2_col7,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow3_col7,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow4_col7,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow5_col7,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow6_col7,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow7_col7,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow8_col7,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow9_col7,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow10_col7,#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow12_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow11_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68alevel0_row0" class="row_heading level0 row0" >lightgbm</th>
#                         <td id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col1" class="data row0 col1" >6.3258</td>
#                         <td id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col2" class="data row0 col2" >81.5683</td>
#                         <td id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col3" class="data row0 col3" >9.0315</td>
#                         <td id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col4" class="data row0 col4" >0.3187</td>
#                         <td id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col5" class="data row0 col5" >0.0045</td>
#                         <td id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col6" class="data row0 col6" >0.0032</td>
#                         <td id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow0_col7" class="data row0 col7" >22.0367</td>
#             </tr>
#             <tr>
#                         <th id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68alevel0_row1" class="row_heading level0 row1" >et</th>
#                         <td id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#                         <td id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow1_col1" class="data row1 col1" >6.5117</td>
#                         <td id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow1_col2" class="data row1 col2" >82.7475</td>
#                         <td id="T_aa6c52ec_c9c4_11ec_9756_00155d40b68arow1_col3" class="data row1 col3" >9.09

# %%
# Create Model (Linear Regression)

with Timer() as elapsed:
    lr = create_model('lr', fold=5)

benchmark_payload = {}
benchmark_payload["function"] = "create model"
benchmark_payload["model"] = "lr"
benchmark_payload["processor"] = "gpu"
benchmark_payload["fit_time"] = elapsed.elapsed

benchmark_list.append(benchmark_payload)
# Out:
# <style  type="text/css" >
# #T_aedc931e_c9c4_11ec_9756_00155d40b68arow5_col0,#T_aedc931e_c9c4_11ec_9756_00155d40b68arow5_col1,#T_aedc931e_c9c4_11ec_9756_00155d40b68arow5_col2,#T_aedc931e_c9c4_11ec_9756_00155d40b68arow5_col3,#T_aedc931e_c9c4_11ec_9756_00155d40b68arow5_col4,#T_aedc931e_c9c4_11ec_9756_00155d40b68arow5_col5{
#             background:  yellow;
#         }</style><table id="T_aedc931e_c9c4_11ec_9756_00155d40b68a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_aedc931e_c9c4_11ec_9756_00155d40b68alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow0_col0" class="data row0 col0" >6.8459</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow0_col1" class="data row0 col1" >92.2263</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow0_col2" class="data row0 col2" >9.6035</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow4_col0" class="data row4 col0" >6.7727</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow4_col1" class="data row4 col1" >90.4165</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow4_col2" class="data row4 col2" >9.5088</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow4_col3" class="data row4 col3" >0.2403</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow4_col4" class="data row4 col4" >0.0048</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow4_col5" class="data row4 col5" >0.0034</td>
#             </tr>
#             <tr>
#                         <th id="T_aedc931e_c9c4_11ec_9756_00155d40b68alevel0_row5" class="row_heading level0 row5" >Mean</th>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow5_col0" class="data row5 col0" >6.8083</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow5_col1" class="data row5 col1" >91.5209</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow5_col2" class="data row5 col2" >9.5666</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow5_col3" class="data row5 col3" >0.2356</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow5_col4" class="data row5 col4" >0.0048</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow5_col5" class="data row5 col5" >0.0034</td>
#             </tr>
#             <tr>
#                         <th id="T_aedc931e_c9c4_11ec_9756_00155d40b68alevel0_row6" class="row_heading level0 row6" >Std</th>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow6_col0" class="data row6 col0" >0.0250</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow6_col1" class="data row6 col1" >0.6577</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow6_col2" class="data row6 col2" >0.0344</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow6_col3" class="data row6 col3" >0.0038</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow6_col4" class="data row6 col4" >0.0000</td>
#                         <td id="T_aedc931e_c9c4_11ec_9756_00155d40b68arow6_col5" class="data row6 col5" >0.0000</td>
#             </tr>
#     </tbody></table>

# %%
# Tune the Linear Regression Model
with Timer() as elasped:
    tuned_lr = tune_model(lr)
    
benchmark_payload = {}
benchmark_payload["function"] = "tune model"
benchmark_payload["model"] = "lr"
benchmark_payload["processor"] = "gpu"
benchmark_payload["fit_time"] = elapsed.elapsed

benchmark_list.append(benchmark_payload)
# Out:
# <style  type="text/css" >
# #T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow3_col0,#T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow3_col1,#T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow3_col2,#T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow3_col3,#T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow3_col4,#T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow3_col5{
#             background:  yellow;
#         }</style><table id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow0_col0" class="data row0 col0" >6.8277</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow0_col1" class="data row0 col1" >91.8777</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow0_col2" class="data row0 col2" >9.5853</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow0_col3" class="data row0 col3" >0.2312</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow0_col4" class="data row0 col4" >0.0048</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow0_col5" class="data row0 col5" >0.0034</td>
#             </tr>
#             <tr>
#                         <th id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow1_col0" class="data row1 col0" >6.7952</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow1_col1" class="data row1 col1" >91.3209</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow1_col2" class="data row1 col2" >9.5562</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow1_col3" class="data row1 col3" >0.2362</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow1_col4" class="data row1 col4" >0.0048</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow1_col5" class="data row1 col5" >0.0034</td>
#             </tr>
#             <tr>
#                         <th id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow2_col0" class="data row2 col0" >6.8021</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow2_col1" class="data row2 col1" >91.3695</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow2_col2" class="data row2 col2" >9.5587</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow2_col3" class="data row2 col3" >0.2392</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow2_col4" class="data row2 col4" >0.0048</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow2_col5" class="data row2 col5" >0.0034</td>
#             </tr>
#             <tr>
#                         <th id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68alevel0_row3" class="row_heading level0 row3" >Mean</th>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow3_col0" class="data row3 col0" >6.8083</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow3_col1" class="data row3 col1" >91.5227</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow3_col2" class="data row3 col2" >9.5667</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow3_col3" class="data row3 col3" >0.2355</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow3_col4" class="data row3 col4" >0.0048</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow3_col5" class="data row3 col5" >0.0034</td>
#             </tr>
#             <tr>
#                         <th id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68alevel0_row4" class="row_heading level0 row4" >Std</th>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow4_col0" class="data row4 col0" >0.0140</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow4_col1" class="data row4 col1" >0.2518</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow4_col2" class="data row4 col2" >0.0132</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow4_col3" class="data row4 col3" >0.0033</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow4_col4" class="data row4 col4" >0.0000</td>
#                         <td id="T_b7f77f4a_c9c4_11ec_9756_00155d40b68arow4_col5" class="data row4 col5" >0.0000</td>
#             </tr>
#     </tbody></table>

# %%
# Ensemble a Model

# %%
# Blender Ensemble Model
with Timer() as elapsed:
    #train individual models to blend
    # xgboost is CPU only
    # xgboost = create_model('xgboost', verbose = False)
    lr = create_model('lr', verbose=False)
    knn = create_model('knn', verbose=False)
    
    #blend individual models
    blender = blend_models(estimator_list = [lr, knn])
    
benchmark_payload = {}
benchmark_payload["function"] = "ensemble - blending"
benchmark_payload["model"] = "Blending lr, knn"
benchmark_payload["processor"] = "gpu"
benchmark_payload["fit_time"] = elapsed.elapsed

benchmark_list.append(benchmark_payload)
# Out:
# <style  type="text/css" >
# #T_5df71d52_c9d8_11ec_9756_00155d40b68arow3_col0,#T_5df71d52_c9d8_11ec_9756_00155d40b68arow3_col1,#T_5df71d52_c9d8_11ec_9756_00155d40b68arow3_col2,#T_5df71d52_c9d8_11ec_9756_00155d40b68arow3_col3,#T_5df71d52_c9d8_11ec_9756_00155d40b68arow3_col4,#T_5df71d52_c9d8_11ec_9756_00155d40b68arow3_col5{
#             background:  yellow;
#         }</style><table id="T_5df71d52_c9d8_11ec_9756_00155d40b68a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr>    <tr>        <th class="index_name level0" >Fold</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5df71d52_c9d8_11ec_9756_00155d40b68alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow0_col0" class="data row0 col0" >6.6221</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow0_col1" class="data row0 col1" >85.2958</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow0_col2" class="data row0 col2" >9.2356</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow0_col3" class="data row0 col3" >0.2863</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow0_col4" class="data row0 col4" >0.0046</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow0_col5" class="data row0 col5" >0.0033</td>
#             </tr>
#             <tr>
#                         <th id="T_5df71d52_c9d8_11ec_9756_00155d40b68alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow1_col0" class="data row1 col0" >6.5888</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow1_col1" class="data row1 col1" >84.7307</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow1_col2" class="data row1 col2" >9.2049</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow1_col3" class="data row1 col3" >0.2914</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow1_col4" class="data row1 col4" >0.0046</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow1_col5" class="data row1 col5" >0.0033</td>
#             </tr>
#             <tr>
#                         <th id="T_5df71d52_c9d8_11ec_9756_00155d40b68alevel0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow2_col0" class="data row2 col0" >6.5884</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow2_col1" class="data row2 col1" >85.0123</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow2_col2" class="data row2 col2" >9.2202</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow2_col3" class="data row2 col3" >0.2921</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow2_col4" class="data row2 col4" >0.0046</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow2_col5" class="data row2 col5" >0.0033</td>
#             </tr>
#             <tr>
#                         <th id="T_5df71d52_c9d8_11ec_9756_00155d40b68alevel0_row3" class="row_heading level0 row3" >Mean</th>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow3_col0" class="data row3 col0" >6.5998</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow3_col1" class="data row3 col1" >85.0129</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow3_col2" class="data row3 col2" >9.2202</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow3_col3" class="data row3 col3" >0.2899</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow3_col4" class="data row3 col4" >0.0046</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow3_col5" class="data row3 col5" >0.0033</td>
#             </tr>
#             <tr>
#                         <th id="T_5df71d52_c9d8_11ec_9756_00155d40b68alevel0_row4" class="row_heading level0 row4" >Std</th>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow4_col0" class="data row4 col0" >0.0158</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow4_col1" class="data row4 col1" >0.2307</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow4_col2" class="data row4 col2" >0.0125</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow4_col3" class="data row4 col3" >0.0026</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow4_col4" class="data row4 col4" >0.0000</td>
#                         <td id="T_5df71d52_c9d8_11ec_9756_00155d40b68arow4_col5" class="data row4 col5" >0.0000</td>
#             </tr>
#     </tbody></table>

# %%
# TODO Fix crash of Python kernel on training
#       of stacked model, and uncomment/run the rest

# Stacking Ensemble Model
# with Timer() as elapsed:
#     stacker = stack_models(best_models)

# benchmark_payload = {}
# benchmark_payload["function"] = "ensemble - stacking"
# benchmark_payload["model"] = "best_models gpu"
# benchmark_payload["processor"] = "gpu"
# benchmark_payload["fit_time"] = elapsed.elapsed

# benchmark_list.append(benchmark_payload)

# %%
# Plot Error of Blender & Stacking Models
plot_model(blender, plot = 'error')
# plot_model(stacker, plot = 'error')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Arial, Liberation Sans, Bitstream Vera Sans, sans-serif

# %%
# Predict on Hold-Out Sample
with Timer() as elapsed:
    predict_model(blender);
    
benchmark_payload = {}
benchmark_payload["function"] = "predict model"
benchmark_payload["model"] = "blender"
benchmark_payload["processor"] = "gpu"
benchmark_payload["fit_time"] = elapsed.elapsed

benchmark_list.append(benchmark_payload)
# Out:
# <style  type="text/css" >
# </style><table id="T_c2c8ee80_c9e8_11ec_9756_00155d40b68a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c2c8ee80_c9e8_11ec_9756_00155d40b68alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c2c8ee80_c9e8_11ec_9756_00155d40b68arow0_col0" class="data row0 col0" >Voting Regressor</td>
#                         <td id="T_c2c8ee80_c9e8_11ec_9756_00155d40b68arow0_col1" class="data row0 col1" >6.4927</td>
#                         <td id="T_c2c8ee80_c9e8_11ec_9756_00155d40b68arow0_col2" class="data row0 col2" >82.3724</td>
#                         <td id="T_c2c8ee80_c9e8_11ec_9756_00155d40b68arow0_col3" class="data row0 col3" >9.0759</td>
#                         <td id="T_c2c8ee80_c9e8_11ec_9756_00155d40b68arow0_col4" class="data row0 col4" >0.3111</td>
#                         <td id="T_c2c8ee80_c9e8_11ec_9756_00155d40b68arow0_col5" class="data row0 col5" >0.0046</td>
#                         <td id="T_c2c8ee80_c9e8_11ec_9756_00155d40b68arow0_col6" class="data row0 col6" >0.0033</td>
#             </tr>
#     </tbody></table>

# %%
# Finalize Blender Ensemble Model and predict with it
with Timer() as elapsed:
    final_blender = finalize_model(blender)
    
benchmark_payload = {}
benchmark_payload["function"] = "finalize model"
benchmark_payload["model"] = "blender"
benchmark_payload["processor"] = "gpu"
benchmark_payload["fit_time"] = elapsed.elapsed

benchmark_list.append(benchmark_payload)
with Timer() as elapsed:
    predict_model(final_blender);

benchmark_payload = {}
benchmark_payload["function"] = "predict model"
benchmark_payload["model"] = "final stacker"
benchmark_payload["processor"] = "gpu"
benchmark_payload["fit_time"] = elapsed.elapsed

benchmark_list.append(benchmark_payload)
# Out:
# <style  type="text/css" >
# </style><table id="T_79e04158_ca03_11ec_9756_00155d40b68a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_79e04158_ca03_11ec_9756_00155d40b68alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_79e04158_ca03_11ec_9756_00155d40b68arow0_col0" class="data row0 col0" >Voting Regressor</td>
#                         <td id="T_79e04158_ca03_11ec_9756_00155d40b68arow0_col1" class="data row0 col1" >5.7705</td>
#                         <td id="T_79e04158_ca03_11ec_9756_00155d40b68arow0_col2" class="data row0 col2" >65.1055</td>
#                         <td id="T_79e04158_ca03_11ec_9756_00155d40b68arow0_col3" class="data row0 col3" >8.0688</td>
#                         <td id="T_79e04158_ca03_11ec_9756_00155d40b68arow0_col4" class="data row0 col4" >0.4555</td>
#                         <td id="T_79e04158_ca03_11ec_9756_00155d40b68arow0_col5" class="data row0 col5" >0.0041</td>
#                         <td id="T_79e04158_ca03_11ec_9756_00155d40b68arow0_col6" class="data row0 col6" >0.0029</td>
#             </tr>
#     </tbody></table>

# %%
# Predict on Unseen Data with the Stack Ensemble Model
with Timer() as elapsed:
    unseen_predictions = predict_model(final_blender, data=unseen_df)
    unseen_predictions.head()
    
benchmark_payload = {}
benchmark_payload["function"] = "predict on unseen"
benchmark_payload["model"] = "final blender"
benchmark_payload["processor"] = "gpu"
benchmark_payload["fit_time"] = elapsed.elapsed

benchmark_list.append(benchmark_payload)
# Out:
# <style  type="text/css" >
# </style><table id="T_148a63a8_ca06_11ec_9756_00155d40b68a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_148a63a8_ca06_11ec_9756_00155d40b68alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_148a63a8_ca06_11ec_9756_00155d40b68arow0_col0" class="data row0 col0" >Voting Regressor</td>
#                         <td id="T_148a63a8_ca06_11ec_9756_00155d40b68arow0_col1" class="data row0 col1" >6.7513</td>
#                         <td id="T_148a63a8_ca06_11ec_9756_00155d40b68arow0_col2" class="data row0 col2" >89.4083</td>
#                         <td id="T_148a63a8_ca06_11ec_9756_00155d40b68arow0_col3" class="data row0 col3" >9.4556</td>
#                         <td id="T_148a63a8_ca06_11ec_9756_00155d40b68arow0_col4" class="data row0 col4" >0.2408</td>
#                         <td id="T_148a63a8_ca06_11ec_9756_00155d40b68arow0_col5" class="data row0 col5" >0.0048</td>
#                         <td id="T_148a63a8_ca06_11ec_9756_00155d40b68arow0_col6" class="data row0 col6" >0.0034</td>
#             </tr>
#     </tbody></table>

# %%
# Write Times to File
outpath = "outputLocal/pycaret_benchmarksCPUvsGPU_justGPU20220501.json"

with open(outpath, "a") as fh:
    fh.write(json.dumps(benchmark_list))
    fh.write("\n")

# %%
# EXAMPLE - Sample Compare_models
# Works, but leaving it commented out as it just runs the same compare_models

# from pycaret.regression import *
# exp_reg = setup(data=df, target ='Year', session_id=632, normalize=True, use_gpu=True)

# top3 = compare_models(exclude=non_gpu_models, n_select=3)
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .            06:53:20
# Status     . . . . . . . . . . . . . . . . . .  Preprocessing Data
# Text(value="Following data types have been inferred automatically, if they are correct press enter to continue…
#          Data Type
# t_avg_1    Numeric
# t_avg_2    Numeric
# t_avg_3    Numeric
# t_avg_4    Numeric
# t_avg_5    Numeric
# ...            ...
# t_cov_75   Numeric
# t_cov_76   Numeric
# t_cov_77   Numeric
# t_cov_78   Numeric
# Year         Label
#
# [91 rows x 1 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_13456/1410640726.py in <module>
#       1 # EXAMPLE - Sample Compare_models
#       2 from pycaret.regression import *
# ----> 3 exp_reg = setup(data=df, target ='Year', session_id=632, normalize=True, use_gpu=True)
#       4
#       5 top3 = compare_models(exclude=non_gpu_models, n_select=3)
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/pycaret/regression.py in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     666         verbose=verbose,
#     667         profile=profile,
# --> 668         profile_kwargs=profile_kwargs,
#     669     )
#     670
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/pycaret/internal/tabular.py in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, experiment_custom_tags, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1406             test_data = pd.concat([X_test, y_test], axis=1)
#    1407
# -> 1408         train_data = prep_pipe.fit_transform(train_data)
#    1409         # workaround to also transform target
#    1410         dtypes.final_training_columns.append(target)
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/sklearn/pipeline.py in fit_transform(self, X, y, **fit_params)
#     365         """
#     366         fit_params_steps = self._check_fit_params(**fit_params)
# --> 367         Xt = self._fit(X, y, **fit_params_steps)
#     368
#     369         last_step = self._final_estimator
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/sklearn/pipeline.py in _fit(self, X, y, **fit_params_steps)
#     294                 message_clsname='Pipeline',
#     295                 message=self._log_message(step_idx),
# --> 296                 **fit_params_steps[name])
#     297             # Replace the transformer of the step with the fitted
#     298             # transformer. This is necessary when loading the transformer
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/joblib/memory.py in __call__(self, *args, **kwargs)
#     350
#     351     def __call__(self, *args, **kwargs):
# --> 352         return self.func(*args, **kwargs)
#     353
#     354     def call_and_shelve(self, *args, **kwargs):
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/sklearn/pipeline.py in _fit_transform_one(transformer, X, y, weight, message_clsname, message, **fit_params)
#     738     with _print_elapsed_time(message_clsname, message):
#     739         if hasattr(transformer, 'fit_transform'):
# --> 740             res = transformer.fit_transform(X, y, **fit_params)
#     741         else:
#     742             res = transformer.fit(X, y, **fit_params).transform(X)
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/pycaret/internal/preprocess.py in fit_transform(self, dataset, y)
#     419
#     420         # since this is for training , we dont nees any transformation since it has already been transformed in fit
# --> 421         data = self.fit(data)
#     422
#     423         # additionally we just need to treat the target variable
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/pycaret/internal/preprocess.py in fit(self, dataset, y)
#     321
#     322             display(dt_print_out[["Data Type"]])
# --> 323             self.response = input()
#     324
#     325             if self.response in [
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1009             self._parent_ident["shell"],
#    1010             self.get_parent("shell"),
# -> 1011             password=False,
#    1012         )
#    1013
#
# ~/.pyenv/versions/3.7.13/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1050             except KeyboardInterrupt:
#    1051                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1052                 raise KeyboardInterrupt("Interrupted by user") from None
#    1053             except Exception:
#    1054                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
